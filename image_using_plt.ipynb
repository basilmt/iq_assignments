# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import urllib

# %%
url = "https://catvills.com/wp-content/uploads/2020/02/dumbest-cat-breeds-f-1.jpg"
plt.imshow(np.array(PIL.Image.open(urllib.request.urlopen(url))))
